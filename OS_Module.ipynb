# %%
import os

# %%
root_dir = 'Dataset_BUSI_with_GT/'
benign_dir = root_dir+'benign/'
malignant_dir = root_dir+'malignant/'

# %%
for path,subdirs,files in os.walk(benign_dir):
    dirname=path.split(os.path.sep)[-1]
    benign_images=os.listdir(path)
    print(benign_images, '\n')
# Out:
# ['benign (1).png', 'benign (1)_mask.png', 'benign (10).png', 'benign (10)_mask.png', 'benign (100).png', 'benign (100)_mask.png', 'benign (100)_mask_1.png', 'benign (101).png', 'benign (101)_mask.png', 'benign (102).png', 'benign (102)_mask.png', 'benign (103).png', 'benign (103)_mask.png', 'benign (104).png', 'benign (104)_mask.png', 'benign (105).png', 'benign (105)_mask.png', 'benign (106).png', 'benign (106)_mask.png', 'benign (107).png', 'benign (107)_mask.png', 'benign (108).png', 'benign (108)_mask.png', 'benign (109).png', 'benign (109)_mask.png', 'benign (11).png', 'benign (11)_mask.png', 'benign (110).png', 'benign (110)_mask.png', 'benign (111).png', 'benign (111)_mask.png', 'benign (112).png', 'benign (112)_mask.png', 'benign (113).png', 'benign (113)_mask.png', 'benign (114).png', 'benign (114)_mask.png', 'benign (115).png', 'benign (115)_mask.png', 'benign (116).png', 'benign (116)_mask.png', 'benign (117).png', 'benign (117)_mask.png', 'benign (118).png', 'benign (118)
# ...

# %%
os.listdir(benign_dir)
# Out:
# ['benign (1).png',
#  'benign (1)_mask.png',
#  'benign (10).png',
#  'benign (10)_mask.png',
#  'benign (100).png',
#  'benign (100)_mask.png',
#  'benign (100)_mask_1.png',
#  'benign (101).png',
#  'benign (101)_mask.png',
#  'benign (102).png',
#  'benign (102)_mask.png',
#  'benign (103).png',
#  'benign (103)_mask.png',
#  'benign (104).png',
#  'benign (104)_mask.png',
#  'benign (105).png',
#  'benign (105)_mask.png',
#  'benign (106).png',
#  'benign (106)_mask.png',
#  'benign (107).png',
#  'benign (107)_mask.png',
#  'benign (108).png',
#  'benign (108)_mask.png',
#  'benign (109).png',
#  'benign (109)_mask.png',
#  'benign (11).png',
#  'benign (11)_mask.png',
#  'benign (110).png',
#  'benign (110)_mask.png',
#  'benign (111).png',
#  'benign (111)_mask.png',
#  'benign (112).png',
#  'benign (112)_mask.png',
#  'benign (113).png',
#  'benign (113)_mask.png',
#  'benign (114).png',
#  'benign (114)_mask.png',
#  'benign (115).png',
#  'benign (115)_mask.png',
# ...

# %%
for file in os.listdir(benign_dir):
    print(file)
# Out:
# benign (1).png
# benign (1)_mask.png
# benign (10).png
# benign (10)_mask.png
# benign (100).png
# benign (100)_mask.png
# benign (100)_mask_1.png
# benign (101).png
# benign (101)_mask.png
# benign (102).png
# benign (102)_mask.png
# benign (103).png
# benign (103)_mask.png
# benign (104).png
# benign (104)_mask.png
# benign (105).png
# benign (105)_mask.png
# benign (106).png
# benign (106)_mask.png
# benign (107).png
# benign (107)_mask.png
# benign (108).png
# benign (108)_mask.png
# benign (109).png
# benign (109)_mask.png
# benign (11).png
# benign (11)_mask.png
# benign (110).png
# benign (110)_mask.png
# benign (111).png
# benign (111)_mask.png
# benign (112).png
# benign (112)_mask.png
# benign (113).png
# benign (113)_mask.png
# benign (114).png
# benign (114)_mask.png
# benign (115).png
# benign (115)_mask.png
# benign (116).png
# benign (116)_mask.png
# benign (117).png
# benign (117)_mask.png
# benign (118).png
# benign (118)_mask.png
# benign (119).png
# ...

# %%
for file in os.listdir(benign_dir):
    if file.endswith('.png'):
        print(file)
# Out:
# benign (1).png
# benign (1)_mask.png
# benign (10).png
# benign (10)_mask.png
# benign (100).png
# benign (100)_mask.png
# benign (100)_mask_1.png
# benign (101).png
# benign (101)_mask.png
# benign (102).png
# benign (102)_mask.png
# benign (103).png
# benign (103)_mask.png
# benign (104).png
# benign (104)_mask.png
# benign (105).png
# benign (105)_mask.png
# benign (106).png
# benign (106)_mask.png
# benign (107).png
# benign (107)_mask.png
# benign (108).png
# benign (108)_mask.png
# benign (109).png
# benign (109)_mask.png
# benign (11).png
# benign (11)_mask.png
# benign (110).png
# benign (110)_mask.png
# benign (111).png
# benign (111)_mask.png
# benign (112).png
# benign (112)_mask.png
# benign (113).png
# benign (113)_mask.png
# benign (114).png
# benign (114)_mask.png
# benign (115).png
# benign (115)_mask.png
# benign (116).png
# benign (116)_mask.png
# benign (117).png
# benign (117)_mask.png
# benign (118).png
# benign (118)_mask.png
# benign (119).png
# ...

# %%
for file in os.walk(benign_dir):
    print(file)
# Out:
# ('Dataset_BUSI_with_GT/benign/', [], ['benign (1).png', 'benign (1)_mask.png', 'benign (10).png', 'benign (10)_mask.png', 'benign (100).png', 'benign (100)_mask.png', 'benign (100)_mask_1.png', 'benign (101).png', 'benign (101)_mask.png', 'benign (102).png', 'benign (102)_mask.png', 'benign (103).png', 'benign (103)_mask.png', 'benign (104).png', 'benign (104)_mask.png', 'benign (105).png', 'benign (105)_mask.png', 'benign (106).png', 'benign (106)_mask.png', 'benign (107).png', 'benign (107)_mask.png', 'benign (108).png', 'benign (108)_mask.png', 'benign (109).png', 'benign (109)_mask.png', 'benign (11).png', 'benign (11)_mask.png', 'benign (110).png', 'benign (110)_mask.png', 'benign (111).png', 'benign (111)_mask.png', 'benign (112).png', 'benign (112)_mask.png', 'benign (113).png', 'benign (113)_mask.png', 'benign (114).png', 'benign (114)_mask.png', 'benign (115).png', 'benign (115)_mask.png', 'benign (116).png', 'benign (116)_mask.png', 'benign (117).png', 'benign (117)_mask.pn
# ...

# %%
keyword = 'mask'
for filename in os.listdir(benign_dir):
    if keyword in filename:
        print(filename)
# Out:
# benign (1)_mask.png
# benign (10)_mask.png
# benign (100)_mask.png
# benign (100)_mask_1.png
# benign (101)_mask.png
# benign (102)_mask.png
# benign (103)_mask.png
# benign (104)_mask.png
# benign (105)_mask.png
# benign (106)_mask.png
# benign (107)_mask.png
# benign (108)_mask.png
# benign (109)_mask.png
# benign (11)_mask.png
# benign (110)_mask.png
# benign (111)_mask.png
# benign (112)_mask.png
# benign (113)_mask.png
# benign (114)_mask.png
# benign (115)_mask.png
# benign (116)_mask.png
# benign (117)_mask.png
# benign (118)_mask.png
# benign (119)_mask.png
# benign (12)_mask.png
# benign (120)_mask.png
# benign (121)_mask.png
# benign (122)_mask.png
# benign (123)_mask.png
# benign (124)_mask.png
# benign (125)_mask.png
# benign (126)_mask.png
# benign (127)_mask.png
# benign (128)_mask.png
# benign (129)_mask.png
# benign (13)_mask.png
# benign (130)_mask.png
# benign (131)_mask.png
# benign (132)_mask.png
# benign (133)_mask.png
# benign (134)_mask.png
# ...

# %%
flood_root_dir = 'mmflood/'

for dirpath,dirnames,filenames in os.walk(flood_root_dir):
    print('Current Path: ', dirpath)
    print('Directories: ', dirnames)
    print('Files: ', filenames)
    print()
# Out:
# Current Path:  mmflood/
# Directories:  ['mmflood']
# Files:  ['activations.json']
#
# Current Path:  mmflood/mmflood
# ...

# %%
directory = "DEM"
 
# Parent Directory = flood_rood_dir

 
# Path
path = os.path.join(flood_root_dir, directory)
print(path)
# Out:
# mmflood/DEM

# %%
os.rmdir(flood_root_dir+'mmflood\EMSR107-1\hydro')

# %%
print(flood_root_dir+'mmflood\EMSR107-1\hydro')
# Out:
# mmflood/mmflood\EMSR107-1\hydro

# %%
import shutil

flood_root_dir = 'mmflood/'
dir_keyword = 'hydro'
dir_keyword2 = 'DEM'

for dirpath,dirnames,filenames in os.walk(flood_root_dir):
    if dir_keyword in dirpath:
       # os.rmdir(dirpath)
        shutil.rmtree(dirpath)
    if dir_keyword2 in dirpath:
        shutil.rmtree(dirpath)

# %%
#flood_root_dir = 'mmflood/'
#dir_keyword2 = 'DEM'

for dirpath,dirnames,filenames in os.walk(flood_root_dir):
    if dir_keyword2 in dirpath:
       # os.rmdir(dirpath)
        shutil.rmtree(dirpath)

# %%
os.listdir(flood_root_dir+'mmflood/')
# Out:
# ['EMSR107-1',
#  'EMSR107-2',
#  'EMSR107-5',
#  'EMSR107-6',
#  'EMSR107-7',
#  'EMSR117-0',
#  'EMSR117-1',
#  'EMSR117-2',
#  'EMSR117-3',
#  'EMSR117-4',
#  'EMSR118-0',
#  'EMSR118-1',
#  'EMSR118-2',
#  'EMSR118-3',
#  'EMSR118-4',
#  'EMSR120-0',
#  'EMSR120-1',
#  'EMSR120-2',
#  'EMSR120-3',
#  'EMSR122-0',
#  'EMSR122-3',
#  'EMSR141-2',
#  'EMSR147-1',
#  'EMSR147-2',
#  'EMSR147-3',
#  'EMSR149-1',
#  'EMSR149-10',
#  'EMSR149-11',
#  'EMSR149-12',
#  'EMSR149-2',
#  'EMSR149-3',
#  'EMSR149-4',
#  'EMSR149-5',
#  'EMSR149-6',
#  'EMSR149-8',
#  'EMSR149-9',
#  'EMSR150-1',
#  'EMSR150-2',
#  'EMSR150-3',
#  'EMSR150-4',
#  'EMSR150-7',
#  'EMSR151-2',
#  'EMSR151-3',
#  'EMSR151-4',
#  'EMSR151-5',
#  'EMSR154-0',
#  'EMSR154-1',
#  'EMSR154-2',
#  'EMSR156-0',
#  'EMSR156-1',
#  'EMSR162-0',
#  'EMSR162-2',
#  'EMSR165-0',
#  'EMSR165-2',
#  'EMSR165-4',
#  'EMSR165-5',
#  'EMSR165-7',
#  'EMSR166-0',
#  'EMSR167-0',
#  'EMSR167-1',
#  'EMSR167-2',
#  'EMSR167-3',
# ...

# %%
root_dir = 'Dataset_BUSI_with_GT/'
benign_dir = root_dir+'benign/'
malignant_dir = root_dir+'malignant/'
normal_dir = root_dir+'normal/'

# %%
os.mkdir(root_dir+'images')

# %%
os.mkdir(root_dir+'masks')

# %%
images_target_dir=root_dir+'images/'
masks_target_dir=root_dir+'masks/'

# %%
import shutil
#RootDir1 = r'*your directory*'
#TargetFolder = r'*your target folder*'
for root, dirs, files in os.walk((os.path.normpath(benign_dir)), topdown=False):
        for name in files:
            if 'mask' in name:
                print ("Found")
                SourceFolder = os.path.join(root,name)
                shutil.move(SourceFolder, masks_target_dir)
# Out:
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# ...

# %%
for root, dirs, files in os.walk((os.path.normpath(malignant_dir)), topdown=False):
        for name in files:
            if 'mask' in name:
                print ("Found")
                SourceFolder = os.path.join(root,name)
                shutil.move(SourceFolder, masks_target_dir)
# Out:
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# ...

# %%
for root, dirs, files in os.walk((os.path.normpath(normal_dir)), topdown=False):
        for name in files:
            if 'mask' in name:
                print ("Found")
                SourceFolder = os.path.join(root,name)
                shutil.move(SourceFolder, masks_target_dir)
# Out:
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# ...

# %%
for root, dirs, files in os.walk((os.path.normpath(benign_dir)), topdown=False):
        for name in files:
            if name.endswith('.png'):
                print ("Found")
                SourceFolder = os.path.join(root,name)
                shutil.move(SourceFolder, images_target_dir)
# Out:
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# ...

# %%
for root, dirs, files in os.walk((os.path.normpath(malignant_dir)), topdown=False):
        for name in files:
            if name.endswith('.png'):
                print ("Found")
                SourceFolder = os.path.join(root,name)
                shutil.move(SourceFolder, images_target_dir)
# Out:
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# ...

# %%
for root, dirs, files in os.walk((os.path.normpath(normal_dir)), topdown=False):
        for name in files:
            if name.endswith('.png'):
                print ("Found")
                SourceFolder = os.path.join(root,name)
                shutil.move(SourceFolder, images_target_dir)
# Out:
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# ...

# %%
os.rmdir(benign_dir)
os.rmdir(malignant_dir)
os.rmdir(normal_dir)

# %%
os.mkdir(root_dir+'data/')

# %%
shutil.move(root_dir+'images/',root_dir+'data/')
# Out:
# 'Dataset_BUSI_with_GT/data/images'

# %%
shutil.move(root_dir+'masks/',root_dir+'data/')
# Out:
# 'Dataset_BUSI_with_GT/data/masks'

# %%
import splitfolders

input_folder = root_dir+'data/'
output_folder = root_dir+'data_for_training_and_testing'

splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.8,.1,.1),group_prefix=None)
# Out:
# Copying files: 1560 files [00:05, 271.60 files/s]

# %%
#removing multiple masks for single image

temp_dir=root_dir+'data/masks/'

for root, dirs, files in os.walk((os.path.normpath(temp_dir)), topdown=False):
        for file in files:
            if 'mask_1' in file:
                print ("Found")
                #os.remove(file)
                SourceFile = os.path.join(root,file)
                os.remove(SourceFile)
            if 'mask_2' in file:
                print ("Found _2")
                #os.remove(file)
                SourceFile = os.path.join(root,file)
                os.remove(SourceFile)
                #shutil.move(SourceFolder, masks_target_dir)
# Out:
# Found _2
